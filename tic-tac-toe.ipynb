# %%
from IPython.display import clear_output

def tic_tac_toe():
 
    empty_squares = ['1',"2","3","4","5","6","7","8","9"]
    full_squares = ["WRONG"]
    move = "WRONG"
# ------------------------------------------------------------------------------------------------------------------------    
#GAME - STATE - ELEMENT

    control_list = ['1',"2","3","4","5","6","7","8","9"]
    inputs = [" "," "," "," "," "," "," "," "," "]
    i = 0
    winning_list = inputs
    
#GAME - STATE - ELEMENT
# ------------------------------------------------------------------------------------------------------------------------    
# ORDER - DECLARATION - ELEMENT     
    
    choice = "WRONG"
    
    while choice not in ["x","o"]:
        #condition 1: STRING CHECK:
        choice = input("Hello, players!\n Player 1, Do you want to play as 'x' or as 'o'?: ")
        
        if choice not in ["x","o"]:
            print("\nSorry, you have to choose either x or o.")
    print(f"\nPlayer 1 is playing as '{choice}'") 
    if choice == 'x':
        choice2 = 'o'
    else:
        choice2 = 'x'
    
# ORDER - DECLARATION - ELEMENT 
# ------------------------------------------------------------------------------------------------------------------------
    
    while empty_squares != []: 
        
        while move not in empty_squares:
            
            move = input("\nChoose an empty position (1 is top-left and 9 is bottom-right): ")
            if move not in empty_squares:
                print("\nSorry, you have to pick an empty square, by its index (1-9) ")
                move = "WRONG"
                
            elif move in full_squares:
                print("\nSorry, you have to pick another square. This one is not empty.")
                
            else:
                print("\nGood job.")       
        clear_output()    
        full_squares.append(move)
        empty_squares.remove(move)
        if len(empty_squares)%2 == 0:
            print("\nNow it is 2nd  player turn.\n")
        else:
            print("\nNow it is 1st player turn.\n")
 #------------------------------------------------------------------------------------------------------------------------
 #GAME - STATE - ELEMENT    
    #INPUT => PLACE ON A BOARD
        
        for number in control_list:
            if move in control_list and len(empty_squares)%2 == 0:
                inputs[control_list.index(move)] = choice
               
                
            elif move in control_list and len(empty_squares)%2 != 0:
                inputs[control_list.index(move)] = choice2
                
            else:
                pass
          
    #PRINT BOARD
        print(" ",inputs[0]," | ",inputs[1],' | ',inputs[2]," ")
        print("-----------------")
        print(" ",inputs[3]," | ",inputs[4],' | ',inputs[5]," ")
        print("-----------------")
        print(" ",inputs[6]," | ",inputs[7],' | ',inputs[8]," \n")
        
 #------------------------------------------------------------------------------------------------------------------------       
        
    #PLAYER ONE WON !
        
        if choice == winning_list[0] == winning_list[1] == winning_list[2]:
            print("The winner is Player 1. Congratulation!")
            break
        elif choice == winning_list[3] == winning_list[4] == winning_list[5]:
            print("The winner is Player 1. Congratulation!")
            break
        elif choice == winning_list[6] == winning_list[7] == winning_list[8]:
            print("The winner is Player 1. Congratulation!")
            break
        elif choice == winning_list[0] == winning_list[3] == winning_list[6]:
            print("The winner is Player 1. Congratulation!")
            break
        elif choice == winning_list[1] == winning_list[4] == winning_list[7]:
            print("The winner is Player 1. Congratulation!")
            break
        elif choice == winning_list[2] == winning_list[5] == winning_list[8]:
            print("The winner is Player 1. Congratulation!")
            break
        elif choice == winning_list[0] == winning_list[4] == winning_list[8]:
            print("The winner is Player 1. Congratulation!")
            break
        elif choice == winning_list[2] == winning_list[4] == winning_list[6]:
            print("The winner is Player 1. Congratulation!")
            break
#------------------------------------------------------------------------------------------------------------------------            
        
    #PLAYER TWO WON !
        
        elif choice2 == winning_list[0] == winning_list[1] == winning_list[2]:
            print("The winner is Player 2. Congratulation!")
            break
        elif choice2 == winning_list[3] == winning_list[4] == winning_list[5]:
            print("The winner is Player 2. Congratulation!")
            break
        elif choice2 == winning_list[6] == winning_list[7] == winning_list[8]:
            print("The winner is Player 2. Congratulation!")
            break
        elif choice2 == winning_list[0] == winning_list[3] == winning_list[6]:
            print("The winner is Player 2. Congratulation!")
            break
        elif choice2 == winning_list[1] == winning_list[4] == winning_list[7]:
            print("The winner is Player 2. Congratulation!")
            break
        elif choice2 == winning_list[2] == winning_list[5] == winning_list[8]:
            print("The winner is Player 2. Congratulation!")
            break
        elif choice2 == winning_list[0] == winning_list[4] == winning_list[8]:
            print("The winner is Player 2. Congratulation!")
            break
        elif choice2 == winning_list[2] == winning_list[4] == winning_list[6]:
            print("The winner is Player 2. Congratulation!")
            break
#------------------------------------------------------------------------------------------------------------------------

#GAME - STATE - ELEMENT
#------------------------------------------------------------------------------------------------------------------------

# %%
tic_tac_toe()
# Out:
# Now it is 2nd  player turn.
#
#   x  |  o  |  o
# -----------------
#      |  x  |
# -----------------
#      |     |  x
#
# The winner is Player 1. Congratulation!
